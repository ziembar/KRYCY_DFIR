# %%
# instalacja paczek, które przydadzą się później

# !pip install nfstream
# Out:
# Requirement already satisfied: nfstream in ./.venv/lib/python3.10/site-packages (6.5.3)
# Requirement already satisfied: cffi>=1.15.0 in ./.venv/lib/python3.10/site-packages (from nfstream) (1.17.1)
# Requirement already satisfied: psutil>=5.8.0 in ./.venv/lib/python3.10/site-packages (from nfstream) (6.1.0)
# Requirement already satisfied: dpkt>=1.9.7 in ./.venv/lib/python3.10/site-packages (from nfstream) (1.9.8)
# Requirement already satisfied: numpy>=1.19.5 in ./.venv/lib/python3.10/site-packages (from nfstream) (2.1.3)
# Requirement already satisfied: pandas>=1.1.5 in ./.venv/lib/python3.10/site-packages (from nfstream) (2.2.3)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=1.15.0->nfstream) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas>=1.1.5->nfstream) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas>=1.1.5->nfstream) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas>=1.1.5->nfstream) (2024.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->nfstream) (1.16.0)

# %%
# import potrzebnych bibliotek do środowiska programistycznego (zostaną wykorzystane później)

import nfstream
from nfstream import NFStreamer
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Pobranie i wczytanie danych do programu

# %%
# Pobranie próbek z logami z sieci (w normalnym wypadku bralibyśmy je najpewniej gdzieś z naszej sieci)
# !wget -O normal_traffic.pcap https://mcfp.felk.cvut.cz/publicDatasets/CTU-Normal-13/2017-07-03_capture-win2.pcap
# !wget -O malicious_traffic.pcap https://mcfp.felk.cvut.cz/publicDatasets/CTU-Malware-Capture-Botnet-14/2013-10-18_capture-win15.pcap


# Wczytanie ruchu normalnego
normal_streamer = NFStreamer(source="normal_traffic.pcap", statistical_analysis = True)
normal_flows = normal_streamer.to_pandas()
normal_flows['label'] = 0  # Oznaczenie ruchu jako normalnego

# Wczytanie ruchu złośliwego
malicious_streamer = NFStreamer(source="malicious_traffic.pcap", statistical_analysis = True)
malicious_flows = malicious_streamer.to_pandas()
malicious_flows['label'] = 1  # Oznaczenie ruchu jako złośliwego

# Połączenie obu zbiorów danych
data = pd.concat([normal_flows, malicious_flows], ignore_index=True)

# Wyświetlenie pierwszych rekordów zbiorów danych
data.head()
# Out:
# --2024-12-20 23:20:04--  https://mcfp.felk.cvut.cz/publicDatasets/CTU-Normal-13/2017-07-03_capture-win2.pcap
# Resolving mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)... 147.32.82.194, 195.113.144.205, 147.32.208.11, ...
# Connecting to mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)|147.32.82.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 506351 (494K) [application/vnd.tcpdump.pcap]
# Saving to: ‘normal_traffic.pcap’
#
# normal_traffic.pcap 100%[===================>] 494.48K  2.98MB/s    in 0.2s
#
# 2024-12-20 23:20:04 (2.98 MB/s) - ‘normal_traffic.pcap’ saved [506351/506351]
#
# --2024-12-20 23:20:05--  https://mcfp.felk.cvut.cz/publicDatasets/CTU-Malware-Capture-Botnet-14/2013-10-18_capture-win15.pcap
# Resolving mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)... 147.32.82.194, 195.113.144.205, 147.32.208.11, ...
# Connecting to mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)|147.32.82.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 477318 (466K) [application/vnd.tcpdump.pcap]
# Saving to: ‘malicious_traffic.pcap’
#
# malicious_traffic.p 100%[===================>] 466.13K  2.54MB/s    in 0.2s
#
# 2024-12-20 23:20:05 (2.54 MB/s) - ‘malicious_traffic.pcap’ saved [477318/477318]
#    id  expiration_id                    src_ip            src_mac   src_oui  \
# 0   0              0  fe80::da58:d7ff:fe00:f72  d8:58:d7:00:0f:72  d8:58:d7
# 1   1              0  fe80::da58:d7ff:fe00:f72  d8:58:d7:00:0f:72  d8:58:d7
# 2   2              0             192.168.1.112  08:00:27:e1:e3:8a  08:00:27
# 3   3              0             192.168.1.112  08:00:27:e1:e3:8a  08:00:27
# 4   4              0             192.168.1.112  08:00:27:e1:e3:8a  08:00:27
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0         0  fe80::5440:d617:fa87:1f07  08:00:27:e1:e3:8a  08:00:27         0
# 1       547  fe80::5440:d617:fa87:1f07  08:00:27:e1:e3:8a  08:00:27       546
# 2     62576                    8.8.8.8  1c:6f:65:c0:43:92  1c:6f:65        53
# 3     52234                    8.8.8.8  1c:6f:65:c0:43:92  1c:6f:65        53
# 4     62804                    8.8.8.8  1c:6f:65:c0:43:92  1c:6f:65        53
#
#    ...  application_name  application_category_name  application_is_guessed  \
# 0  ...            ICMPV6                    Network                       0
# 1  ...            DHCPV6                    Network                       0
# 2  ...     DNS.Microsoft                    Network                       0
# 3  ...     DNS.Microsoft                    Network                       0
# 4  ...     DNS.Microsoft                    Network                       0
#
#    application_confidence  requested_server_name  client_fingerprint  \
# 0                       6                    NaN                 NaN
# 1                       6                    NaN                 NaN
# 2                       6       www.msftncsi.com                 NaN
# 3                       6       www.msftncsi.com                 NaN
# 4                       6       www.msftncsi.com                 NaN
#
#    server_fingerprint  user_agent  content_type  label
# 0                 NaN         NaN           NaN      0
# 1                 NaN         NaN           NaN      0
# 2                 NaN         NaN           NaN      0
# 3                 NaN         NaN           NaN      0
# 4                 NaN         NaN           NaN      0
#
# [5 rows x 87 columns]

# %% [markdown]
# ## Eksploracja i czyszczenie danych

# %%
# Wyświetlenie podstawowych informacji o zbiorach danych
data.info()

# Usuwanie kolumn, które mają tylko jedną unikalną wartość lub brakujące wartości
for col in data.columns:
    if data[col].nunique() == 1 or data[col].isnull().any():
        data.drop(col, inplace=True, axis=1)

# Wyświetlenie liczby rekordów po czyszczeniu
print(f"Liczba rekordów po czyszczeniu: {data.shape[0]}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 87 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            450 non-null    int64
#  1   expiration_id                 450 non-null    int64
#  2   src_ip                        450 non-null    object
#  3   src_mac                       450 non-null    object
#  4   src_oui                       450 non-null    object
#  5   src_port                      450 non-null    int64
#  6   dst_ip                        450 non-null    object
#  7   dst_mac                       450 non-null    object
#  8   dst_oui                       450 non-null    object
#  9   dst_port                      450 non-null    int64
#  10  protocol                      450 non-null    int64
#  11  ip_version                    450 non-null    int64
#  12  vlan_id                       450 non-null    int64
#  13  tunnel_id                     450 non-null    int64
#  14  bidirectional_first_seen_ms   450 non-null    int64
#  15  bidirectional_last_seen_ms    450 non-null    int64
#  16  bidirectional_duration_ms     450 non-null    int64
#  17  bidirectional_packets         450 non-null    int64
#  18  bidirectional_bytes           450 non-null    int64
#  19  src2dst_first_seen_ms         450 non-null    int64
#  20  src2dst_last_seen_ms          450 non-null    int64
#  21  src2dst_duration_ms           450 non-null    int64
#  22  src2dst_packets               450 non-null    int64
#  23  src2dst_bytes                 450 non-null    int64
#  24  dst2src_first_seen_ms         450 non-null    int64
#  25  dst2src_last_seen_ms          450 non-null    int64
#  26  dst2src_duration_ms           450 non-null    int64
#  27  dst2src_packets               450 non-null    int64
#  28  dst2src_bytes                 450 non-null    int64
#  29  bidirectional_min_ps          450 non-null    int64
#  30  bidirectional_mean_ps         450 non-null    float64
#  31  bidirectional_stddev_ps       450 non-null    float64
#  32  bidirectional_max_ps          450 non-null    int64
#  33  src2dst_min_ps                450 non-null    int64
#  34  src2dst_mean_ps               450 non-null    float64
#  35  src2dst_stddev_ps             450 non-null    float64
#  36  src2dst_max_ps                450 non-null    int64
#  37  dst2src_min_ps                450 non-null    int64
#  38  dst2src_mean_ps               450 non-null    float64
#  39  dst2src_stddev_ps             450 non-null    float64
#  40  dst2src_max_ps                450 non-null    int64
#  41  bidirectional_min_piat_ms     450 non-null    int64
#  42  bidirectional_mean_piat_ms    450 non-null    float64
#  43  bidirectional_stddev_piat_ms  450 non-null    float64
#  44  bidirectional_max_piat_ms     450 non-null    int64
#  45  src2dst_min_piat_ms           450 non-null    int64
#  46  src2dst_mean_piat_ms          450 non-null    float64
#  47  src2dst_stddev_piat_ms        450 non-null    float64
#  48  src2dst_max_piat_ms           450 non-null    int64
#  49  dst2src_min_piat_ms           450 non-null    int64
#  50  dst2src_mean_piat_ms          450 non-null    float64
#  51  dst2src_stddev_piat_ms        450 non-null    float64
#  52  dst2src_max_piat_ms           450 non-null    int64
#  53  bidirectional_syn_packets     450 non-null    int64
#  54  bidirectional_cwr_packets     450 non-null    int64
#  55  bidirectional_ece_packets     450 non-null    int64
#  56  bidirectional_urg_packets     450 non-null    int64
#  57  bidirectional_ack_packets     450 non-null    int64
#  58  bidirectional_psh_packets     450 non-null    int64
#  59  bidirectional_rst_packets     450 non-null    int64
#  60  bidirectional_fin_packets     450 non-null    int64
#  61  src2dst_syn_packets           450 non-null    int64
#  62  src2dst_cwr_packets           450 non-null    int64
#  63  src2dst_ece_packets           450 non-null    int64
#  64  src2dst_urg_packets           450 non-null    int64
#  65  src2dst_ack_packets           450 non-null    int64
#  66  src2dst_psh_packets           450 non-null    int64
#  67  src2dst_rst_packets           450 non-null    int64
#  68  src2dst_fin_packets           450 non-null    int64
#  69  dst2src_syn_packets           450 non-null    int64
#  70  dst2src_cwr_packets           450 non-null    int64
#  71  dst2src_ece_packets           450 non-null    int64
#  72  dst2src_urg_packets           450 non-null    int64
#  73  dst2src_ack_packets           450 non-null    int64
#  74  dst2src_psh_packets           450 non-null    int64
#  75  dst2src_rst_packets           450 non-null    int64
#  76  dst2src_fin_packets           450 non-null    int64
#  77  application_name              450 non-null    object
#  78  application_category_name     450 non-null    object
#  79  application_is_guessed        450 non-null    int64
#  80  application_confidence        450 non-null    int64
#  81  requested_server_name         53 non-null     object
#  82  client_fingerprint            24 non-null     object
#  83  server_fingerprint            24 non-null     object
#  84  user_agent                    3 non-null      object
#  85  content_type                  3 non-null      object
#  86  label                         450 non-null    int64
# dtypes: float64(12), int64(62), object(13)
# memory usage: 306.0+ KB
# Liczba rekordów po czyszczeniu: 450

# %%
# Eksperymenty - eksploracja szczegółowa

# Wyświetlenie unikalnych wartości w kolumnach (można wybrać kolumnę do analizy)
column_name = 'src_ip'  # Przykład nazwy kolumny
print("Unikalne wartości w kolumnie:", column_name)
print(data[column_name].unique())

# Eksploracja liczby rekordów dla każdej etykiety
print("Liczba rekordów dla każdej etykiety:")
print(data['label'].value_counts())

# Histogramy dla wybranych cech numerycznych (należy odkomentować i zmodyfikować)
# data['some_numeric_column'].hist(bins=30)
# plt.title('Histogram cechy some_numeric_column')
# plt.show()
# Out:
# Unikalne wartości w kolumnie: src_ip
# ['fe80::da58:d7ff:fe00:f72' '192.168.1.112' 'fd2d:ab8c:225::1'
#  'fd2d:ab8c:225:0:79ec:26b9:bb98:fae8' 'fe80::a866:72ce:9643:c9b1' '::'
#  '10.0.2.115' '10.0.2.2']
# Liczba rekordów dla każdej etykiety:
# label
# 1    403
# 0     47
# Name: count, dtype: int64

# %% [markdown]
# ## Analiza korelacji cech

# %%
import seaborn as sns

# Wybranie tylko kolumn numerycznych (int i float)
data = data.select_dtypes(include=[np.number])

# Sprawdzenie, czy kolumna 'label' istnieje w danych
if 'label' in data.columns:
    # Obliczanie korelacji wszystkich cech z etykietą
    correlation_with_label = data.corr()['label'].sort_values(key=abs, ascending=False)

    # Usunięcie korelacji etykiety z samą sobą
    correlation_with_label = correlation_with_label.drop('label', errors='ignore')

    # Wybór 10 najbardziej skorelowanych cech
    top_10_correlated_features = correlation_with_label.head(10)

    print("10 cech najbardziej skorelowanych z etykietą:\n", top_10_correlated_features)

    # Wizualizacja korelacji tych cech z etykietą
    plt.figure(figsize=(10, 6))
    sns.barplot(x=top_10_correlated_features.index, y=top_10_correlated_features.values, palette='viridis')
    plt.title('Top 10 cech najbardziej skorelowanych z etykietą')
    plt.xlabel('Cechy')
    plt.ylabel('Współczynnik korelacji')
    plt.xticks(rotation=45)  # Obrót etykiet osi X dla lepszej czytelności
    plt.show()
else:
    print("Brak kolumny 'label' w danych.")
# Out:
# 10 cech najbardziej skorelowanych z etykietą:
#  bidirectional_min_ps          0.813236
# src2dst_min_ps                0.812468
# src_port                     -0.810491
# bidirectional_min_piat_ms     0.794612
# dst2src_first_seen_ms        -0.759012
# bidirectional_mean_piat_ms    0.734732
# dst2src_mean_ps              -0.731854
# dst2src_max_ps               -0.717738
# dst2src_last_seen_ms         -0.702513
# bidirectional_stddev_ps      -0.694309
# Name: label, dtype: float64
# /tmp/ipykernel_124046/2078466250.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_correlated_features.index, y=top_10_correlated_features.values, palette='viridis')

# %%
# Eksperymenty - analiza wybranych korelacji

# Wybór korelacji do szczegółowej analizy (należy odkomentować i zmodyfikować)
# feature1 = 'source_port'
# feature2 = 'destination_port'
# sns.scatterplot(x=data[feature1], y=data[feature2])
# plt.title(f'Korelacja między {feature1} a {feature2}')
# plt.show()

# %% [markdown]
# ## Przygotowanie danych do modelowania

# %%
X = data.drop('label', axis=1)
y = data['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Budowanie i trenowanie modelu

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

def train_and_evaluate_decision_tree(X_train, y_train, X_test, y_test, max_depth=None, criterion='gini'):
    # Trenowanie modelu Decision Tree z określonymi parametrami
    tree_model = DecisionTreeClassifier(max_depth=max_depth, criterion=criterion, random_state=42)
    tree_model.fit(X_train, y_train)

    # Przewidywanie na zestawie testowym
    predictions = tree_model.predict(X_test)

    # Obliczenie metryk
    accuracy = accuracy_score(y_test, predictions)
    conf_matrix = confusion_matrix(y_test, predictions)

    # Wizualizacja drzewa
    plt.figure(figsize=(20,10))
    plot_tree(tree_model, filled=True, feature_names=X_train.columns, class_names=['Normal', 'Malicious'], fontsize=10)
    plt.title("Wizualizacja drzewa decyzyjnego")
    plt.show()

    return tree_model, accuracy, conf_matrix

# %%
# Trenowanie i ocena modelu z domyślnymi parametrami
default_model, default_accuracy, default_conf_matrix = train_and_evaluate_decision_tree(X_train, y_train, X_test, y_test)

print("Dokładność modelu z domyślnymi parametrami:", default_accuracy)
print(default_conf_matrix)
sns.heatmap(default_conf_matrix, annot=True, fmt="d")
plt.title("Macierz błędów - Model domyślny")
plt.show()
# Out:
# Dokładność modelu z domyślnymi parametrami: 1.0

# %% [markdown]
# ## Interaktywne testowanie parametrów modelu

# %%
from ipywidgets import interactive

def interactive_decision_tree_testing(max_depth, criterion):
    _, new_accuracy, new_conf_matrix = train_and_evaluate_decision_tree(X_train, y_train, X_test, y_test, max_depth, criterion)

    print("Dokładność modelu na nowym zestawie danych:", new_accuracy)
    sns.heatmap(new_conf_matrix, annot=True, fmt="d", cmap='viridis')
    plt.title("Macierz błędów na nowym zestawie danych")
    plt.show()

# Stworzenie interaktywnego widgetu do eksperymentowania z parametrami
interactive_plot = interactive(interactive_decision_tree_testing,
                               max_depth=(1, 20, 1),
                               criterion=["gini", "entropy"])
interactive_plot
# Out:
# interactive(children=(IntSlider(value=10, description='max_depth', max=20, min=1), Dropdown(description='crite…

# %% [markdown]
# **Zadanie:** spróbuj z innymi zbiorami danych, np. spośród tych https://mcfp.felk.cvut.cz/publicDatasets/ (uwaga na rozmiary zbiorów, dla dużych objętności będzie to trwało bardzo długo). W tym celu najlepiej przerabiać kod powyżej, albo przeklejać komórki na nowo poniżej i edytować je w tym miejscu.
